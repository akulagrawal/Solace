# %%
import json

# %%
with open('convertcsv.json') as f:
    data = json.load(f)

# %%
print(data)
# Out:
# [{'Longitude': 145.616, 'Latitude': 19.246, 'Magnitude': 6}, {'Longitude': 127.352, 'Latitude': 1.8630000000000002, 'Magnitude': 5.8}, {'Longitude': -173.972, 'Latitude': -20.579, 'Magnitude': 6.2}, {'Longitude': -23.557, 'Latitude': -59.076, 'Magnitude': 5.8}, {'Longitude': 126.427, 'Latitude': 11.937999999999999, 'Magnitude': 5.8}, {'Longitude': 166.62900000000002, 'Latitude': -13.405, 'Magnitude': 6.7}, {'Longitude': 87.867, 'Latitude': 27.357, 'Magnitude': 5.9}, {'Longitude': 166.21200000000002, 'Latitude': -13.309000000000001, 'Magnitude': 6}, {'Longitude': -27.043000000000003, 'Latitude': -56.452, 'Magnitude': 6}, {'Longitude': 178.487, 'Latitude': -24.563000000000002, 'Magnitude': 5.8}, {'Longitude': 108.988, 'Latitude': -6.807, 'Magnitude': 5.9}, {'Longitude': 125.95200000000001, 'Latitude': -2.608, 'Magnitude': 8.2}, {'Longitude': 161.703, 'Latitude': 54.636, 'Magnitude': 5.5}, {'Longitude': -177.864, 'Latitude': -18.697, 'Magnitude': 5.6}, {'Longitude': 73.251, 'Latitude': 
# ...

# %%
print(data[0])
# Out:
# {'Longitude': 145.616, 'Latitude': 19.246, 'Magnitude': 6}

# %%
print(len(data))
# Out:
# 23412
