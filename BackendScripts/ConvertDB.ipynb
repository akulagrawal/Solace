# %%
import pandas as pd

# %%
df = pd.read_csv('database.csv')

# %%
df.head()
# Out:
#          Date      Time  Latitude  Longitude        Type  Depth  Depth Error  \
# 0  01/02/1965  13:44:18    19.246    145.616  Earthquake  131.6          NaN
# 1  01/04/1965  11:29:49     1.863    127.352  Earthquake   80.0          NaN
# 2  01/05/1965  18:05:58   -20.579   -173.972  Earthquake   20.0          NaN
# 3  01/08/1965  18:49:43   -59.076    -23.557  Earthquake   15.0          NaN
# 4  01/09/1965  13:32:50    11.938    126.427  Earthquake   15.0          NaN
#
#    Depth Seismic Stations  Magnitude Magnitude Type    ...      \
# 0                     NaN        6.0             MW    ...
# 1                     NaN        5.8             MW    ...
# 2                     NaN        6.2             MW    ...
# 3                     NaN        5.8             MW    ...
# 4                     NaN        5.8             MW    ...
#
#    Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 0                         NaN            NaN                  NaN
# ...

# %%
df1 = pd.DataFrame()

# %%
df1['Latitude'] = df['Latitude']

# %%
df1['Longitude'] = df['Longitude']

# %%
df1['Magnitude'] = df['Magnitude']

# %%
df1
# Out:
#        Latitude  Longitude  Magnitude
# 0       19.2460   145.6160        6.0
# 1        1.8630   127.3520        5.8
# 2      -20.5790  -173.9720        6.2
# 3      -59.0760   -23.5570        5.8
# 4       11.9380   126.4270        5.8
# 5      -13.4050   166.6290        6.7
# 6       27.3570    87.8670        5.9
# 7      -13.3090   166.2120        6.0
# 8      -56.4520   -27.0430        6.0
# 9      -24.5630   178.4870        5.8
# 10      -6.8070   108.9880        5.9
# 11      -2.6080   125.9520        8.2
# 12      54.6360   161.7030        5.5
# 13     -18.6970  -177.8640        5.6
# 14      37.5230    73.2510        6.0
# 15     -51.8400   139.7410        6.1
# 16      51.2510   178.7150        8.7
# 17      51.6390   175.0550        6.0
# 18      52.5280   172.0070        5.7
# 19      51.6260   175.7460        5.8
# 20      51.0370   177.8480        5.9
# 21      51.7300   173.9750        5.9
# 22      51.7750   173.0580        5.7
# 23      52.6110   172.5880        5.7
# ...

# %%
df1.to_csv('dataset.csv', index = False)
